# %% [markdown]
# <a href="https://colab.research.google.com/github/241541601038-glitch/JALIZ/blob/main/EX_01CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3b4589e1-e22e-47b9-a5bd-f0fb9af38186" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b4589e1-e22e-47b9-a5bd-f0fb9af38186">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread('two.jpg.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
import matplotlib.pyplot as plt

resized_image=cv2.resize(image,(300,100))
plt.imshow(cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
plt.imshow(gray_image,cmap='gray')
plt.axis('off')
plt.show()
plt.imshow(cv2.cvtColor(hsv_image,cv2.COLOR_HSV2RGB))
plt.axis('off')
plt.show()

# %%
0(h,w)= image.shape[:2]
center = (w/2,h/2)
matrix = cv2.getRotationMatrix2D(center,45,1.0)
rotated_image = cv2.warpAffine(image,matrix,(w,h))
plt.imshow(cv2.cvtColor(rotated_image,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2
from google.colab.patches import cv2_imshow
blurred_image = cv2.GaussianBlur(image,(15,15),0)
cv2.imwrite('blurred_image.jpg',blurred_image)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
